# %%
import pandas as pd

# %% [markdown]
# # Model

# %%
from MODEL import DataDrivenRankingSystem

# %%
cluster_ipl_bat = DataDrivenRankingSystem('/Users/rahuljogi/Desktop/@S4/ML/Project__/Datasets/IPL/pre_processed_data_ipl_bat.csv',2)
cluster_ipl1 = cluster_ipl_bat.process('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/IPL/IPL_CLUSTERED_BAT.csv',2)
print(cluster_ipl1.head(5))
# Out:
# /Users/rahuljogi/Desktop/@S4/ML/Project__/MODEL.py:83: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_means = self.df.groupby('Cluster').mean()
# Best Clustering Method: KMeans
# Best Silhouette Score: 0.7962311138706364
#                 Runs  Strikerate          4s         6s  Rank
# Cluster
# 0        1318.076923  137.294117  119.461538  53.974359   1.0
# 1         112.295000   98.628515    8.855000   4.860000   2.0

# %%
cluster_ipl_ball = DataDrivenRankingSystem('/Users/rahuljogi/Desktop/@S4/ML/Project__/Datasets/IPL/pre_processed_data_ipl_ball.csv',2)
cluster_ipl2 = cluster_ipl_ball.process('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/IPL/IPL_CLUSTERED_BALL.csv',2)
print(cluster_ipl2.head(5))
# Out:
# /Users/rahuljogi/Desktop/@S4/ML/Project__/MODEL.py:83: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_means = self.df.groupby('Cluster').mean()
# Best Clustering Method: KMeans
# Best Silhouette Score: 0.7050985554595507
#           Maidens    Wickets        Dots  Runs_Conceded  Rank
# Cluster
# 1        1.196078  44.411765  341.196078    1213.254902   1.0
# 0        0.134969   6.018405   47.871166     200.263804   2.0

# %%
cluster_bbl_bat = DataDrivenRankingSystem('/Users/rahuljogi/Desktop/@S4/ML/Project__/Datasets/BBL/pre_processed_data_bbl_bat.csv',2)
cluster_bbl1 = cluster_bbl_bat.process('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/BBL/BBL_CLUSTERED_BAT.csv',2)
print(cluster_bbl1.head(10))
# Out:
# /Users/rahuljogi/Desktop/@S4/ML/Project__/MODEL.py:83: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_means = self.df.groupby('Cluster').mean()
# Best Clustering Method: KMeans
# Best Silhouette Score: 0.6426781545743173
#               Inns        Runs        Avg  Strikerate         4s         6s  \
# Cluster
# 0        13.225000  329.625000  31.331250  136.222250  29.825000  11.750000
# 1         4.438776   48.112245  12.267551  103.424592   3.826531   1.734694
#
#          Rank
# Cluster
# 0         1.0
# 1         2.0

# %%
cluster_bbl_ball = DataDrivenRankingSystem('/Users/rahuljogi/Desktop/@S4/ML/Project__/Datasets/BBL/pre_processed_data_bbl_ball.csv',2)
cluster_bbl2 = cluster_bbl_ball.process('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/BBL/BBL_CLUSTERED_BALL.csv',2)
print(cluster_bbl2.head(5))
# Out:
# /Users/rahuljogi/Desktop/@S4/ML/Project__/MODEL.py:83: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_means = self.df.groupby('Cluster').mean()
# Best Clustering Method: KMeans
# Best Silhouette Score: 0.6441572179132484
#               Inns        Runs        Avg  Strikerate   Wickets  Best_Bowilng  \
# Cluster
# 0        12.550000  337.900000  33.125599   24.106395  13.72500     20.700000
# 1         3.709677   79.419355  31.011762   24.196975   2.83871     17.435484
#
#           Economy        4w        5w  Rank
# Cluster
# 0        8.142335  0.275000  0.050000   1.0
# 1        9.299950  0.032258  0.032258   2.0

# %%
cluster_wc_bat = DataDrivenRankingSystem('/Users/rahuljogi/Desktop/@S4/ML/Project__/Datasets/WC/pre_processed_data_WC_BAT.csv',2)
cluster_wc1 = cluster_wc_bat.process('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/WC/WC_CLUSTERED_BAT.csv',2)
print(cluster_wc1.head(10))
# Out:
# /Users/rahuljogi/Desktop/@S4/ML/Project__/MODEL.py:83: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_means = self.df.groupby('Cluster').mean()
# Best Clustering Method: KMeans
# Best Silhouette Score: 0.66154145190774
#              Inns        Runs        Avg  Strikerate         4s         6s  \
# Cluster
# 0        8.857143  378.095238  50.377381   98.814286  36.000000  10.833333
# 1        4.798077   72.557692  16.499423   80.227885   7.009615   1.817308
#
#          Rank
# Cluster
# 0         1.0
# 1         2.0

# %%
cluster_wc_ball = DataDrivenRankingSystem('/Users/rahuljogi/Desktop/@S4/ML/Project__/Datasets/WC/pre_processed_data_WC_BALL.csv',2)
cluster_wc2 = cluster_wc_ball.process('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/WC/WC_CLUSTERED_BALL.csv',2)
print(cluster_wc2.head(5))
# Out:
# /Users/rahuljogi/Desktop/@S4/ML/Project__/MODEL.py:83: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_means = self.df.groupby('Cluster').mean()
# Best Clustering Method: Hierarchical
# Best Silhouette Score: 0.585204725923991
#                Runs        Avg  Strikerate    Wickets   Economy        4w  \
# Cluster
# 1        407.878049  37.906341   40.393171  12.243902  5.664390  0.317073
# 0        124.081967  32.678689   31.695902   3.065574  6.661475  0.081967
#
#                6w  Rank
# Cluster
# 1        0.097561   1.0
# 0        0.049180   2.0

# %% [markdown]
# # IPL_BAT

# %%
dr = pd.read_csv('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/IPL/IPL_clustered_BAT.csv')

# %%
dr.head()
# Out:
#             Player    Runs  Strikerate     4s    6s  Cluster Grade
# 0  Ruturaj Gaikwad   839.0  132.125984   80.0  29.0        0     A
# 1   Faf du Plessis  1640.0  133.659332  155.0  58.0        0     A
# 2    Robin Uthappa   944.0  124.538259   85.0  43.0        0     A
# 3        Moeen Ali   666.0  146.373626   52.0  42.0        1     B
# 4     Shubman Gill  1417.0  123.003472  137.0  36.0        0     A

# %%
dra = dr[dr['Grade']=='A']
dra.head()
# Out:
#             Player    Runs  Strikerate     4s    6s  Cluster Grade
# 0  Ruturaj Gaikwad   839.0  132.125984   80.0  29.0        0     A
# 1   Faf du Plessis  1640.0  133.659332  155.0  58.0        0     A
# 2    Robin Uthappa   944.0  124.538259   85.0  43.0        0     A
# 4     Shubman Gill  1417.0  123.003472  137.0  36.0        0     A
# 6      Nitish Rana  1383.0  133.623188  130.0  64.0        0     A

# %%
drb = dr[dr['Grade']=='B']
drb.head()
# Out:
#              Player   Runs  Strikerate    4s    6s  Cluster Grade
# 3         Moeen Ali  666.0  146.373626  52.0  42.0        1     B
# 5    Venkatesh Iyer  370.0  128.472222  37.0  14.0        1     B
# 7      Sunil Narine  683.0  168.226601  70.0  45.0        1     B
# 8       Eoin Morgan  551.0  124.943311  40.0  30.0        1     B
# 10  Shakib Al Hasan  295.0  115.686275  29.0   6.0        1     B

# %%
drc = dr[dr['Grade']=='C']
drc.head()
# Out:
# Empty DataFrame
# Columns: [Player, Runs, Strikerate, 4s, 6s, Cluster, Grade]
# Index: []

# %% [markdown]
# # IPL_BALL

# %%
dr = pd.read_csv('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/IPL/IPL_clustered_BALL.csv')

# %%
dra = dr[dr['Grade']=='A']
dra.head()
# Out:
#                Player  Maidens  Wickets  Dots  Runs_Conceded  Cluster Grade
# 0     Shakib Al Hasan        0       20   177            769        1     A
# 1         Shivam Mavi        2       25   218            715        1     A
# 3  Varun Chakravarthy        0       36   268            839        1     A
# 4        Sunil Narine        1       58   564           1889        1     A
# 6       Deepak Chahar        6       59   570           1681        1     A

# %%
drb = dr[dr['Grade']=='B']
drb.head()
# Out:
#              Player  Maidens  Wickets  Dots  Runs_Conceded  Cluster Grade
# 2   Lockie Ferguson        1       24   197            648        0     B
# 5    Venkatesh Iyer        0        3    14             69        0     B
# 7    Josh Hazlewood        0       12   118            357        0     B
# 17    George Garton        0        3    32            135        0     B
# 20    Glenn Maxwell        0       18   133            561        0     B

# %%
drc = dr[dr['Grade']=='C']
drc.head()
# Out:
# Empty DataFrame
# Columns: [Player, Maidens, Wickets, Dots, Runs_Conceded, Cluster, Grade]
# Index: []

# %% [markdown]
# # BBL_BAT

# %%
dr = pd.read_csv('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/BBL/BBL_clustered_BAT.csv')

# %%
dra = dr[dr['Grade']=='A']
dra.head()
# Out:
#            Player  Inns   Runs    Avg  Strikerate  4s  6s  Cluster Grade
# 0      Alex Hales  15.0  537.0  38.36      159.82  54  30        0     A
# 1     James Vince  16.0  536.0  38.29      143.32  59  11        0     A
# 2  Josh Phillippe  16.0  504.0  31.50      148.24  55  14        0     A
# 3      Chris Lynn  13.0  456.0  35.08      154.05  39  26        0     A
# 4     Colin Munro  15.0  443.0  31.64      128.03  32  19        0     A

# %%
drb = dr[dr['Grade']=='B']
drb.head()
# Out:
#                 Player  Inns   Runs    Avg  Strikerate  4s  6s  Cluster Grade
# 40        Sam Heazlett   9.0  180.0  22.50      135.34  14   9        1     B
# 41           Joe Burns  11.0  180.0  22.50      125.00  18   5        1     B
# 42         Aaron Finch  13.0  179.0  13.77      113.29  20   3        1     B
# 43  Marnus Labuschagne   6.0  176.0  29.33      123.08  13   3        1     B
# 44       Lewis Gregory  12.0  173.0  19.22      133.08  13   8        1     B

# %%
drc = dr[dr['Grade']=='C']
drc.head()
# Out:
# Empty DataFrame
# Columns: [Player, Inns, Runs, Avg, Strikerate, 4s, 6s, Cluster, Grade]
# Index: []

# %% [markdown]
# # BBL_BALL

# %%
dr = pd.read_csv('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/BBL/BBL_clustered_BALL.csv')

# %%
dra = dr[dr['Grade']=='A']
dra.head()
# Out:
#             Player               TEAM  Inns  Runs        Avg  Strikerate  \
# 0  Jhye Richardson    Perth Scorchers    17   463  15.965517   12.724138
# 1    Ben Dwarshuis      Sydney Sixers    13   403  16.791667   11.375000
# 2    Mark Steketee      Brisbane Heat    16   522  21.750000   14.083250
# 3         Wes Agar  Adelaide Strikers    15   457  20.772727   14.909182
# 4   Tanveer Sangha     Sydney Thunder    15   394  18.761905   13.571429
#
#    Wickets  Best_Bowilng   Economy  4w  5w  Cluster Grade
# 0       29            20  7.528455   2   0        0     A
# 1       24             9  8.857143   1   0        0     A
# 2       24            29  9.266327   1   0        0     A
# 3       22            23  8.359705   1   0        0     A
# 4       21            10  8.294737   1   0        0     A

# %%
drb = dr[dr['Grade']=='B']
drb.head()
# Out:
#                  Player                 TEAM  Inns  Runs        Avg  \
# 20     Mujeeb Ur Rahman        Brisbane Heat     8   188  13.428571
# 26  Nathan Coulter-Nile      Melbourne Stars     6   172  15.636364
# 29            Zak Evans  Melbourne Renegades     5   146  14.600000
# 30   Marnus Labuschagne        Brisbane Heat     6   146  14.600000
# 34      Brendan Doggett       Sydney Thunder     5   120  13.333333
#
#     Strikerate  Wickets  Best_Bowilng   Economy  4w  5w  Cluster Grade
# 20   12.857143       14            10  6.266667   0   1        1     B
# 26   11.908909       11             6  7.877983   1   0        1     B
# 29    9.000000       10            28  9.733333   0   1        1     B
# 30   10.200000       10            10  8.588235   0   0        1     B
# 34   12.066667        9            18  6.629834   1   0        1     B

# %%
drc = dr[dr['Grade']=='C']
drc.head()
# Out:
# Empty DataFrame
# Columns: [Player, TEAM, Inns, Runs, Avg, Strikerate, Wickets, Best_Bowilng, Economy, 4w, 5w, Cluster, Grade]
# Index: []

# %% [markdown]
# # ICC_BAT

# %%
dr = pd.read_csv('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/WC/WC_clustered_BAT.csv')

# %%
dra = dr[dr['Grade']=='A']
dra.head()
# Out:
#           Player  Inns  Runs    Avg  Strikerate  4s  6s  Cluster Grade
# 1       DJ Malan     9   404  44.89      101.00  50   9        0     A
# 2        JE Root     9   276  30.67       88.46  21   2        0     A
# 11     DP Conway    10   372  41.33      101.64  54   4        0     A
# 13    R Ravindra    10   578  64.22      106.45  55  17        0     A
# 14  Fakhar Zaman     4   220  73.33      122.91  14  18        0     A

# %%
drb = dr[dr['Grade']=='B']
drb.head()
# Out:
#            Player  Inns  Runs    Avg  Strikerate  4s  6s  Cluster Grade
# 0     JM Bairstow     9   215  23.89       88.48  27   3        1     B
# 3        HC Brook     6   169  28.17      112.67  20   5        1     B
# 4          MM Ali     6    95  15.83       74.80   8   1        1     B
# 5      JC Buttler     9   138  15.33       97.18  11   5        1     B
# 6  LS Livingstone     6    60  10.00       63.83   6   0        1     B

# %%
drc = dr[dr['Grade']=='C']
drc.head()
# Out:
# Empty DataFrame
# Columns: [Player, Inns, Runs, Avg, Strikerate, 4s, 6s, Cluster, Grade]
# Index: []

# %% [markdown]
# # ICC_BALL

# %%
dr = pd.read_csv('/Users/rahuljogi/Desktop/@S4/ML/Project__/Results/WC/WC_clustered_BALL.csv')

# %%
dra = dr[dr['Grade']=='A']
dra.head()
# Out:
#           Player  Runs    Avg  Strikerate  Wickets Best_Bowilng  Economy  4w  \
# 0         A Dutt   426  42.60       46.50       10         3/44     5.50   0
# 1        A Zampa   515  22.39       25.04       23          4/8     5.36   3
# 7      AU Rashid   413  27.53       31.87       15         3/42     5.18   0
# 9   BFW de Leede   487  30.44       25.12       16         4/62     7.27   1
# 12   CAK Rajitha   336  42.00       36.75        8         4/50     6.86   1
#
#     6w  Cluster Grade
# 0    0        1     A
# 1    0        1     A
# 7    0        1     A
# 9    0        1     A
# 12   0        1     A

# %%
drb = dr[dr['Grade']=='B']
drb.head()
# Out:
#            Player  Runs    Avg  Strikerate  Wickets Best_Bowilng  Economy  4w  \
# 2    AAP Atkinson   146  36.50       36.00        4         2/45     6.08   0
# 3      AD Mathews   107  17.83       22.17        6         2/14     4.83   0
# 4     Agha Salman    46   0.00        0.00        0         0/21     9.20   0
# 5      AK Markram    85  85.00      111.00        1         1/23     4.59   0
# 6  AL Phehlukwayo    36  36.00       42.00        1         1/36     5.14   0
#
#    6w  Cluster Grade
# 2   0        0     B
# 3   0        0     B
# 4   0        0     B
# 5   0        0     B
# 6   0        0     B

# %%
drc = dr[dr['Grade']=='C']
drc.head()
# Out:
# Empty DataFrame
# Columns: [Player, Runs, Avg, Strikerate, Wickets, Best_Bowilng, Economy, 4w, 6w, Cluster, Grade]
# Index: []
